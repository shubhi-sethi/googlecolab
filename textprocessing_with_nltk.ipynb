# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhi-sethi/googlecolab/blob/master/textprocessing_with_nltk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66cec736-611d-4068-872e-7b6f80bcf65d" name="files[]" multiple disabled />
#      <output id="result-66cec736-611d-4068-872e-7b6f80bcf65d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WikiQA-dev.txt to WikiQA-dev.txt

# %%
import nltk

# %%
file = open('WikiQA-dev.txt')
print(file.read())
# Out:
# How are epithelial tissues joined together ?	Cross section of sclerenchyma fibers in plant ground tissue	0
# How are epithelial tissues joined together ?	Microscopic view of a histologic specimen of human lung tissue stained with hematoxylin and eosin .	0
# How are epithelial tissues joined together ?	In Biology , Tissue is a cellular organizational level intermediate between cells and a complete organism .	0
# How are epithelial tissues joined together ?	A tissue is an ensemble of similar cells from the same origin that together carry out a specific function .	0
# How are epithelial tissues joined together ?	Organs are then formed by the functional grouping together of multiple tissues .	0
# How are epithelial tissues joined together ?	The study of tissue is known as histology or , in connection with disease , histopathology .	0
# ...

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...

# %%
from nltk.corpus import stopwords
stopwords.words("english")
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
import nltk
FileName = ("WikiQA-dev.txt")

with open(FileName, 'r') as file:
     lines_in_file = file.read()
     nltk_tokens = nltk.word_tokenize(lines_in_file)
     print (nltk_tokens)
     print ("\n")
     print ("Number of Words: " , len(nltk_tokens))
# Out:
# ['How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'Cross', 'section', 'of', 'sclerenchyma', 'fibers', 'in', 'plant', 'ground', 'tissue', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'Microscopic', 'view', 'of', 'a', 'histologic', 'specimen', 'of', 'human', 'lung', 'tissue', 'stained', 'with', 'hematoxylin', 'and', 'eosin', '.', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'In', 'Biology', ',', 'Tissue', 'is', 'a', 'cellular', 'organizational', 'level', 'intermediate', 'between', 'cells', 'and', 'a', 'complete', 'organism', '.', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'A', 'tissue', 'is', 'an', 'ensemble', 'of', 'similar', 'cells', 'from', 'the', 'same', 'origin', 'that', 'together', 'carry', 'out', 'a', 'specific', 'function', '.', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'Organs', 'are', 'then', 'formed', 'by', 'the', 'functional', 'grouping', 'together',
# ...

# %%
FileName = ("WikiQA-dev.txt")
with open(FileName, 'r') as file:
     lines_in_file = file.read()
     print (lines_in_file.split())
     print ("\n")
     print ("Number of Words: ", len(lines_in_file.split()))
# Out:
# ['How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'Cross', 'section', 'of', 'sclerenchyma', 'fibers', 'in', 'plant', 'ground', 'tissue', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'Microscopic', 'view', 'of', 'a', 'histologic', 'specimen', 'of', 'human', 'lung', 'tissue', 'stained', 'with', 'hematoxylin', 'and', 'eosin', '.', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'In', 'Biology', ',', 'Tissue', 'is', 'a', 'cellular', 'organizational', 'level', 'intermediate', 'between', 'cells', 'and', 'a', 'complete', 'organism', '.', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'A', 'tissue', 'is', 'an', 'ensemble', 'of', 'similar', 'cells', 'from', 'the', 'same', 'origin', 'that', 'together', 'carry', 'out', 'a', 'specific', 'function', '.', '0', 'How', 'are', 'epithelial', 'tissues', 'joined', 'together', '?', 'Organs', 'are', 'then', 'formed', 'by', 'the', 'functional', 'grouping', 'together',
# ...

# %%
with open ("WikiQA-dev.txt", "r") as BigFile:

     data=BigFile.readlines()

     for i in range(len(data)):
          print ("Line No- ",i)
          print (data[i])
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Line No-  1067
# what percentage of the human body is water	Extracellular fluid ( 1/3 of body water ) .	0
#
# Line No-  1068
# what percentage of the human body is water	Per Guyton 's illustration , for a 40 litre body , about 15 litres is extracellular , which amounts to 37.5 % Again , this is close to the 1/3 rule of thumb cited here .	0
#
# Line No-  1069
# what percentage of the human body is water	Plasma ( 1/5 of extracellular fluid ) .	0
#
# Line No-  1070
# what percentage of the human body is water	Per Guyton 's illustration , of the 15 litres of extracellular fluid , plasma volume averages 3 litres .	0
#
# Line No-  1071
# what percentage of the human body is water	This amounts to 20 % , the same as per Netter 's Atlas .	0
#
# Line No-  1072
# what percentage of the human body is water	Interstitial fluid ( 4/5 of extracellular fluid )	0
#
# Line No-  1073
# ...

# %%
pip install file-read-backwards

# %%
from file_read_backwards import FileReadBackwards
with FileReadBackwards("WikiQA-dev.txt", encoding="utf-8") as BigFile:
# getting lines by lines starting from the last line up
      for line in BigFile:
           print (line)
# Out:
# What is St. Lucia Known for ?	It is also a member of la Francophonie .	0
# What is St. Lucia Known for ?	The island nation celebrates this every year with a public holiday .	0
# What is St. Lucia Known for ?	On 22 February 1979 , Saint Lucia became an independent state of the Commonwealth of Nations associated with the United Kingdom .	0
# What is St. Lucia Known for ?	From 1958 to 1962 , the island was a member of the Federation of the West Indies .	0
# What is St. Lucia Known for ?	Representative government came about in 1924 ( with universal suffrage from 1953 ) .	0
# What is St. Lucia Known for ?	The financial sector has weathered the global financial crisis , but the recession has hurt tourism .	0
# What is St. Lucia Known for ?	The judiciary is independent and conducts generally fair public trials .	0
# What is St. Lucia Known for ?	Saint Lucia has a legal system based on English common law .	0
# ...

# %%
import nltk
word_data = "The Sky is blue also the ocean is blue also Rainbow has a blue colour."
# First Word tokenization
nltk_tokens = nltk.word_tokenize(word_data)
ordered_tokens = set()
result = []
for word in nltk_tokens:
    if word not in ordered_tokens:
       ordered_tokens.add(word)
       result.append(word)
print (result)
# Out:
# ['The', 'Sky', 'is', 'blue', 'also', 'the', 'ocean', 'Rainbow', 'has', 'a', 'colour', '.']
